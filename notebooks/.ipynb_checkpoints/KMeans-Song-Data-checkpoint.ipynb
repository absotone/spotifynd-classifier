# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 
# %matplotlib inline 

import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# ## Loading in the song data

# %%
df = pd.read_csv("../data/data.csv")

df.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  169909.000000  169909.000000  1.699090e+05  169909.000000
# mean        0.493214       0.538150  2.314062e+05       0.488593
# std         0.376627       0.175346  1.213219e+05       0.267390
# min         0.000000       0.000000  5.108000e+03       0.000000
# 25%         0.094500       0.417000  1.710400e+05       0.263000
# 50%         0.492000       0.548000  2.086000e+05       0.481000
# 75%         0.888000       0.667000  2.629600e+05       0.710000
# max         0.996000       0.988000  5.403500e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  169909.000000     169909.000000  169909.000000  169909.000000
# mean        0.084863          0.161937       5.200519       0.206690
# std         0.278679          0.309329       3.515257       0.176796
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
df.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# ...

# %% [markdown]
# ## Abstracting away relevant columns

# %%
song_data = df[["acousticness","danceability","energy","instrumentalness","key","liveness","loudness","speechiness","tempo","valence"]]

song_data.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0         0.995         0.708  0.1950             0.563   10    0.1510
# 1         0.994         0.379  0.0135             0.901    8    0.0763
# 2         0.604         0.749  0.2200             0.000    5    0.1190
# 3         0.995         0.781  0.1300             0.887    1    0.1110
# 4         0.990         0.210  0.2040             0.908   11    0.0980
#
#    loudness  speechiness    tempo  valence
# 0   -12.428       0.0506  118.469   0.7790
# 1   -28.454       0.0462   83.972   0.0767
# 2   -19.924       0.9290  107.177   0.8800
# 3   -14.734       0.0926  108.003   0.7200
# 4   -16.829       0.0424   62.149   0.0693

# %% [markdown]
# ## Plotting the correlation Matrix and further removal of columns from the dataset

# %%
plt.figure(figsize=(12,10))
sns.heatmap(song_data.corr(),annot=True)
plt.show()

# %% [markdown]
# We see that
# $corr(Loudness,Energy)$ = 0,78 and $corr(Acousticness,Energy)$ = 0,75
#
# So, we can expect reasonably similar results if we remove Loudness and Acousticness from the classification algorithm - this will also make the algorithm faster.

# %%
song_data.columns
# Out:
# Index(['acousticness', 'danceability', 'energy', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence'],
#       dtype='object')

# %%
song_data = song_data[['danceability', 'energy', 'instrumentalness', 'key', 'liveness', 'speechiness', 'tempo', 'valence']]

song_data.head()
# Out:
#    danceability  energy  instrumentalness  key  liveness  speechiness  \
# 0         0.708  0.1950             0.563   10    0.1510       0.0506
# 1         0.379  0.0135             0.901    8    0.0763       0.0462
# 2         0.749  0.2200             0.000    5    0.1190       0.9290
# 3         0.781  0.1300             0.887    1    0.1110       0.0926
# 4         0.210  0.2040             0.908   11    0.0980       0.0424
#
#      tempo  valence
# 0  118.469   0.7790
# 1   83.972   0.0767
# 2  107.177   0.8800
# 3  108.003   0.7200
# 4   62.149   0.0693

# %% [markdown]
# ## Fit the song data to the KMeans Clustering Algorithm - for lower computational resources

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 10,
               random_state= 42).fit(song_data)

# %%
song_data['predicted_label'] = kmeans.predict(song_data)

song_data.head()
# Out:
#    danceability  energy  instrumentalness  key  liveness  speechiness  \
# 0         0.708  0.1950             0.563   10    0.1510       0.0506
# 1         0.379  0.0135             0.901    8    0.0763       0.0462
# 2         0.749  0.2200             0.000    5    0.1190       0.9290
# 3         0.781  0.1300             0.887    1    0.1110       0.0926
# 4         0.210  0.2040             0.908   11    0.0980       0.0424
#
#      tempo  valence  predicted_label
# 0  118.469   0.7790                8
# 1   83.972   0.0767                6
# 2  107.177   0.8800                0
# 3  108.003   0.7200                0
# 4   62.149   0.0693                2

# %%
song_data.sample(1)
# Out:
#         danceability  energy  instrumentalness  key  liveness  speechiness  \
# 124466         0.725   0.259          0.000003    2     0.112       0.0382
#
#           tempo  valence  predicted_label
# 124466  133.849      0.2                7

# %% [markdown]
# ## Save the Model

# %%
import pickle

# %%
filename = "simplemodel.sav"
pickle.dump(kmeans, open(filename, 'wb'))
